# %%
import pandas as pd
import pickle
import os

# 1. Load the previously trained KNN model and saved features
with open('knn_salary_model.pkl', 'rb') as f:
    saved_data = pickle.load(f)
        
knn_model = saved_data['model']
selector = saved_data['selector']
expected_features = saved_data['feature_names']

print("Model loaded successfully.\n")

print("-" * 50)
print("EMPLOYEE SALARY PREDICTOR (KNN)")
print("-" * 50)
print("Please enter the following details:\n")

# 2. Ask the user for input dynamically
user_input = {}

for feature in expected_features:
    val = input(f"Enter value for '{feature}': ").strip()
    user_input[feature] = [float(val)]

# 3. Convert the user's answers into a DataFrame table
input_df = pd.DataFrame(user_input)

# 4. Display the entered data
print("\n" + "-" * 50)
print("DATA ENTERED:")
print("-" * 50)
for feature, val in user_input.items():
    print(f" - {feature}: {val[0]}")
print("-" * 50)

# 5. Make the prediction
predicted_salary = knn_model.predict(input_df)[0]

print(f"\nPREDICTED SALARY: ₹ {predicted_salary:,.2f}")
print("-" * 50)
# Out:
# Model loaded successfully.
#
# --------------------------------------------------
# EMPLOYEE SALARY PREDICTOR (KNN)
# --------------------------------------------------
# Please enter the following details:
#
#
# --------------------------------------------------
# DATA ENTERED:
# --------------------------------------------------
#  - Age: 30.0
#  - Experience: 8.0
#  - JobRole: 1.0
#  - PerformanceRating: 4.0
#  - ProjectsCompleted: 20.0
#  - LeadershipScore: 6.5
#  - Promotions: 1.0
#  - LocationType: 1.0
# --------------------------------------------------
#
# PREDICTED SALARY: ₹ 2,035,277.01
# --------------------------------------------------
# c:\Users\HP Pavilion\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2684: UserWarning: X has feature names, but KNeighborsRegressor was fitted without feature names
#   warnings.warn(

# %%
import pandas as pd
import pickle
import os

# 1. Load the previously trained KNN model and saved features
with open('knn_salary_model.pkl', 'rb') as f:
    saved_data = pickle.load(f)
        
knn_model = saved_data['model']
selector = saved_data['selector']
expected_features = saved_data['feature_names']

print("Model loaded successfully.\n")

print("-" * 50)
print("EMPLOYEE SALARY PREDICTOR (KNN)")
print("-" * 50)
print("Please enter the following details:\n")

# 2. Ask the user for input dynamically
user_input = {}

for feature in expected_features:
    val = input(f"Enter value for '{feature}': ").strip()
    user_input[feature] = [float(val)]

# 3. Convert the user's answers into a DataFrame table
input_df = pd.DataFrame(user_input)

# 4. Display the entered data
print("\n" + "-" * 50)
print("DATA ENTERED:")
print("-" * 50)
for feature, val in user_input.items():
    print(f" - {feature}: {val[0]}")
print("-" * 50)

# 5. Make the prediction
predicted_salary = knn_model.predict(input_df)[0]

print(f"\nPREDICTED SALARY: ₹ {predicted_salary:,.2f}")
print("-" * 50)
# Out:
# Model loaded successfully.
#
# --------------------------------------------------
# EMPLOYEE SALARY PREDICTOR (KNN)
# --------------------------------------------------
# Please enter the following details:
#
#
# --------------------------------------------------
# DATA ENTERED:
# --------------------------------------------------
#  - Age: 20.0
#  - Experience: 5.0
#  - JobRole: 1.0
#  - PerformanceRating: 10.0
#  - ProjectsCompleted: 25.0
#  - LeadershipScore: 8.0
#  - Promotions: 1.0
#  - LocationType: 1.0
# --------------------------------------------------
#
# PREDICTED SALARY: ₹ 2,109,779.53
# --------------------------------------------------
# c:\Users\HP Pavilion\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2684: UserWarning: X has feature names, but KNeighborsRegressor was fitted without feature names
#   warnings.warn(
